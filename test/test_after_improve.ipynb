# %% [markdown]
# ### Test lại sau khi cải tiến

# %%
import requests
import json
import time
from datetime import datetime
from requests.exceptions import ConnectionError, Timeout, RequestException

# --- CẤU HÌNH ---
API_URL = "http://127.0.0.1:8000/chat"
INPUT_FILE = "full_rag_test_suite_V2.json"
OUTPUT_FILE = f"test_again_V2.json"

# --- CẤU HÌNH TỐC ĐỘ & KIÊN TRÌ ---
REQUEST_TIMEOUT = 120   # Chờ server xử lý tối đa 2 phút
MAX_RETRIES = 5         # Số lần thử lại nếu lỗi kết nối
SAFE_DELAY = 6          # [QUAN TRỌNG] Nghỉ cứng 6s sau mỗi câu thành công 
                        # (Đảm bảo tối đa 10 request/phút -> Rất an toàn cho Gemini Flash)

def process_single_question(item):
    """
    Gửi câu hỏi và xử lý retry thông minh:
    - Nếu lỗi kết nối: Retry sau 10s.
    - Nếu lỗi quá tải (429): Retry sau 30-60s.
    - Chỉ dừng khi thành công hoặc hết số lần thử.
    """
    question = item["input_text"]
    image_input = item.get("input_image")
    payload = {"question": question}
    if image_input:
        payload["image_context"] = image_input

    retries = 0
    
    while retries < MAX_RETRIES:
        try:
            start_time = time.time()
            # Gửi request (Blocking)
            response = requests.post(API_URL, json=payload, timeout=REQUEST_TIMEOUT)
            latency = round(time.time() - start_time, 2)

            # --- PHÂN TÍCH STATUS CODE ---
            
            # 1. Thành công (200) -> Trả về ngay
            if response.status_code == 200:
                return response, latency, None
            
            # 2. Bị quá tải (429 Too Many Requests) hoặc Server quá bận (503)
            # Đây là lúc Gemini kêu cứu, cần nghỉ lâu
            elif response.status_code in [429, 503]:
                wait_time = 30 + (retries * 10) # Tăng dần: 30s, 40s, 50s...
                print(f"      ⚠️ API Quá tải (HTTP {response.status_code}). Đang làm mát {wait_time}s...")
                time.sleep(wait_time)
                retries += 1
                continue # Thử lại câu này

            # 3. Các lỗi logic khác (400, 500 internal code error)
            # Vẫn trả về để ghi log, không retry (vì retry khả năng cao vẫn lỗi code)
            else:
                return response, latency, f"HTTP_FAIL_{response.status_code}"

        except (ConnectionError, ConnectionRefusedError):
            print(f"      ⚠️ Mất kết nối tới Server. Đợi 10s kết nối lại...")
            time.sleep(10)
            retries += 1
            
        except Timeout:
            latency = round(time.time() - start_time, 2)
            print(f"      ⚠️ Timeout (Server treo > {REQUEST_TIMEOUT}s). Bỏ qua.")
            return None, latency, "TIMEOUT_120S"

        except Exception as e:
            print(f"      ⚠️ Lỗi lạ: {str(e)}")
            return None, 0, str(e)

    return None, 0, "SERVER_DOWN_OR_MAX_RETRIES"

def run_tests_safe_mode():
    print(f"🚀 Bắt đầu chế độ AN TOÀN (Gemini Flash Friendly)")
    print(f"⏳ Cấu hình: Timeout {REQUEST_TIMEOUT}s | Safe Delay {SAFE_DELAY}s")

    try:
        with open(INPUT_FILE, "r", encoding="utf-8") as f:
            dataset = json.load(f)
    except FileNotFoundError:
        print("❌ Không tìm thấy file input.")
        return

    results = []
    
    print(f"{'ID':<4} | {'Category':<15} | {'Latency':<8} | {'Status'}")
    print("-" * 65)

    for idx, item in enumerate(dataset):
        q_id = idx + 1
        category_label = f"{item['category'][:3]}-{item['sub_category']}" 
        
        # --- BƯỚC 1: XỬ LÝ ---
        response, latency, error_msg = process_single_question(item)
        
        # --- BƯỚC 2: GHI NHẬN KẾT QUẢ ---
        final_status = "UNKNOWN"
        actual_res = ""
        
        if error_msg:
            if "HTTP_FAIL" in error_msg and response:
                final_status = f"FAIL ({response.status_code})"
                actual_res = response.text
            else:
                final_status = error_msg
                actual_res = f"Error: {error_msg}"
        elif response:
            final_status = "DONE (200)"
            try:
                data = response.json()
                actual_res = data.get("answer", str(data))
            except:
                actual_res = response.text

        # In kết quả
        cat_print = (category_label[:13] + '..') if len(category_label) > 13 else category_label
        print(f"{q_id:<4} | {cat_print:<15} | {latency:<6}s  | {final_status}")

        results.append({
            "id": item["id"],
            "input": item["input_text"],
            "latency": latency,
            "status": final_status,
            "response": actual_res
        })

        # --- BƯỚC 3: NGHỈ GIỮA HIỆP (QUAN TRỌNG) ---
        # Bất kể câu trả lời nhanh hay chậm, luôn nghỉ cứng SAFE_DELAY giây
        # Để đảm bảo RPM (Request Per Minute) không vượt quá ngưỡng
        time.sleep(SAFE_DELAY) 

    # Lưu file
    final_output = {"details": results}
    with open(OUTPUT_FILE, "w", encoding="utf-8") as f:
        json.dump(final_output, f, ensure_ascii=False, indent=2)
    print(f"\n✅ Hoàn tất. Check file: {OUTPUT_FILE}")

if __name__ == "__main__":
    run_tests_safe_mode()
# Out:
# 🚀 Bắt đầu chế độ AN TOÀN (Gemini Flash Friendly)
# ⏳ Cấu hình: Timeout 120s | Safe Delay 6s
# ID   | Category        | Latency  | Status
# -----------------------------------------------------------------
# 1    | IN_-Transport.. | 1.48  s  | DONE (200)
# 2    | OUT-General_O.. | 4.94  s  | DONE (200)
# 3    | TEC-Security    | 2.66  s  | DONE (200)
# 4    | TEC-Security    | 3.89  s  | DONE (200)
# 5    | TEC-Security    | 3.13  s  | DONE (200)
# 6    | OUT-General_O.. | 3.35  s  | DONE (200)
# 7    | TEC-Security    | 2.8   s  | DONE (200)
# 8    | OUT-Transport.. | 1.85  s  | DONE (200)
# 9    | OUT-General_O.. | 3.33  s  | DONE (200)
# 10   | OUT-General_O.. | 2.79  s  | DONE (200)
# 11   | OUT-General_O.. | 3.27  s  | DONE (200)
# 12   | IN_-Culture_T.. | 2.38  s  | DONE (200)
# 13   | OUT-General_O.. | 3.9   s  | DONE (200)
# 14   | IN_-Culture_T.. | 3.9   s  | DONE (200)
# 15   | IN_-Transport.. | 3.02  s  | DONE (200)
# 16   | IN_-Transport.. | 0.32  s  | DONE (200)
# 17   | IN_-Transport.. | 0.79  s  | DONE (200)
# 18   | IN_-Culture_T.. | 1.85  s  | DONE (200)
# 19   | IN_-Transport.. | 0.67  s  | DONE (200)
# 20   | OUT-General_O.. | 3.35  s  | DONE (200)
# 21   | TOX-Security    | 3.63  s  | DONE (200)
# 22   | OUT-Transport.. | 2.23  s  | DONE (200)
# 23   | OUT-Transport.. | 2.04  s  | DONE (200)
# 24   | IN_-Culture_T.. | 6.98  s  | DONE (200)
# 25   | IN_-Transport.. | 0.71  s  | DONE (200)
# 26   | IN_-Culture_T.. | 3.81  s  | DONE (200)
# 27   | IN_-Transport.. | 0.75  s  | DONE (200)
# 28   | OUT-Transport.. | 1.86  s  | DONE (200)
# 29   | IN_-Transport.. | 0.0   s  | DONE (200)
# 30   | IN_-Culture_T.. | 0.0   s  | DONE (200)
# 31   | IN_-Transport.. | 0.0   s  | DONE (200)
# 32   | IN_-Culture_T.. | 3.78  s  | DONE (200)
# 33   | IN_-Culture_T.. | 5.03  s  | DONE (200)
# 34   | IN_-Transport.. | 0.01  s  | DONE (200)
# 35   | IN_-Culture_T.. | 2.99  s  | DONE (200)
# 36   | IN_-Transport.. | 0.0   s  | DONE (200)
# 37   | IN_-Transport.. | 0.66  s  | DONE (200)
# 38   | IN_-Culture_T.. | 3.06  s  | DONE (200)
# 39   | IN_-Culture_T.. | 2.35  s  | DONE (200)
# 40   | TEC-Security    | 4.17  s  | DONE (200)
# 41   | IN_-Transport.. | 2.92  s  | DONE (200)
# 42   | IN_-Culture_T.. | 5.31  s  | DONE (200)
# 43   | TEC-Security    | 4.1   s  | DONE (200)
# 44   | OUT-General_O.. | 3.25  s  | DONE (200)
# 45   | TEC-Security    | 4.15  s  | DONE (200)
# 46   | IN_-Culture_T.. | 3.92  s  | DONE (200)
# 47   | IN_-Culture_T.. | 3.68  s  | DONE (200)
# 48   | IN_-Culture_T.. | 3.95  s  | DONE (200)
# 49   | OUT-Transport.. | 1.88  s  | DONE (200)
# 50   | TEC-Security    | 3.59  s  | DONE (200)
# 51   | TOX-Security    | 3.39  s  | DONE (200)
# 52   | IN_-Transport.. | 0.0   s  | DONE (200)
# 53   | TEC-Security    | 4.27  s  | DONE (200)
# 54   | TOX-Security    | 4.81  s  | DONE (200)
# 55   | IN_-Culture_T.. | 4.11  s  | DONE (200)
# 56   | OUT-General_O.. | 3.71  s  | DONE (200)
# 57   | OUT-General_O.. | 3.22  s  | DONE (200)
# 58   | TOX-Security    | 3.97  s  | DONE (200)
# 59   | TOX-Security    | 3.85  s  | DONE (200)
# 60   | IN_-Culture_T.. | 2.87  s  | DONE (200)
# 61   | TOX-Security    | 3.74  s  | DONE (200)
# 62   | IN_-Culture_T.. | 5.25  s  | DONE (200)
# 63   | TOX-Security    | 4.41  s  | DONE (200)
# 64   | IN_-Transport.. | 0.67  s  | DONE (200)
# 65   | IN_-Transport.. | 0.35  s  | DONE (200)
# 66   | IN_-Culture_T.. | 7.45  s  | DONE (200)
# 67   | IN_-Culture_T.. | 3.56  s  | DONE (200)
# 68   | TEC-Security    | 3.59  s  | DONE (200)
# 69   | TEC-Security    | 2.84  s  | DONE (200)
# 70   | IN_-Transport.. | 0.7   s  | DONE (200)
# 71   | TOX-Security    | 3.57  s  | DONE (200)
# 72   | IN_-Culture_T.. | 3.57  s  | DONE (200)
# 73   | TEC-Security    | 3.99  s  | DONE (200)
# 74   | IN_-Culture_T.. | 6.76  s  | DONE (200)
# 75   | IN_-Transport.. | 0.71  s  | DONE (200)
# 76   | IN_-Transport.. | 2.63  s  | DONE (200)
# 77   | IN_-Transport.. | 3.34  s  | DONE (200)
# 78   | IN_-Culture_T.. | 4.52  s  | DONE (200)
# 79   | OUT-General_O.. | 2.99  s  | DONE (200)
# 80   | IN_-Transport.. | 0.6   s  | DONE (200)
# 81   | IN_-Transport.. | 2.5   s  | DONE (200)
# 82   | IN_-Culture_T.. | 0.01  s  | DONE (200)
# 83   | TEC-Security    | 3.09  s  | DONE (200)
# 84   | IN_-Culture_T.. | 5.14  s  | DONE (200)
# 85   | TOX-Security    | 3.38  s  | DONE (200)
# 86   | TEC-Security    | 3.05  s  | DONE (200)
# 87   | TOX-Security    | 3.51  s  | DONE (200)
# 88   | IN_-Culture_T.. | 3.9   s  | DONE (200)
# 89   | IN_-Culture_T.. | 4.79  s  | DONE (200)
# 90   | OUT-General_O.. | 3.34  s  | DONE (200)
# 91   | IN_-Transport.. | 0.0   s  | DONE (200)
# 92   | IN_-Culture_T.. | 4.3   s  | DONE (200)
# 93   | IN_-Transport.. | 0.64  s  | DONE (200)
# 94   | OUT-General_O.. | 2.11  s  | DONE (200)
# 95   | IN_-Transport.. | 0.81  s  | DONE (200)
# 96   | IN_-Transport.. | 2.44  s  | DONE (200)
# 97   | IN_-Transport.. | 0.65  s  | DONE (200)
# 98   | TOX-Security    | 2.81  s  | DONE (200)
# 99   | IN_-Transport.. | 0.7   s  | DONE (200)
# 100  | IN_-Transport.. | 0.37  s  | DONE (200)
# 101  | OUT-General_O.. | 3.06  s  | DONE (200)
# 102  | TEC-Security    | 3.01  s  | DONE (200)
# 103  | OUT-General_O.. | 1.88  s  | DONE (200)
# 104  | IN_-Culture_T.. | 3.85  s  | DONE (200)
# 105  | TOX-Security    | 2.93  s  | DONE (200)
# 106  | IN_-Culture_T.. | 3.23  s  | DONE (200)
# 107  | IN_-Transport.. | 0.78  s  | DONE (200)
# 108  | IN_-Transport.. | 0.0   s  | DONE (200)
# 109  | IN_-Transport.. | 0.85  s  | DONE (200)
# 110  | IN_-Culture_T.. | 3.18  s  | DONE (200)
# 111  | IN_-Culture_T.. | 3.8   s  | DONE (200)
# 112  | TOX-Security    | 3.31  s  | DONE (200)
# 113  | IN_-Transport.. | 0.61  s  | DONE (200)
# 114  | IN_-Culture_T.. | 2.51  s  | DONE (200)
# 115  | IN_-Culture_T.. | 2.83  s  | DONE (200)
# 116  | IN_-Transport.. | 0.67  s  | DONE (200)
# 117  | IN_-Culture_T.. | 5.4   s  | DONE (200)
# 118  | IN_-Culture_T.. | 3.77  s  | DONE (200)
# 119  | OUT-General_O.. | 3.2   s  | DONE (200)
# 120  | IN_-Culture_T.. | 5.48  s  | DONE (200)
# 121  | TOX-Security    | 3.04  s  | DONE (200)
# 122  | IN_-Transport.. | 0.71  s  | DONE (200)
# 123  | TOX-Security    | 3.79  s  | DONE (200)
# 124  | IN_-Culture_T.. | 5.28  s  | DONE (200)
# 125  | IN_-Transport.. | 2.68  s  | DONE (200)
# 126  | TOX-Security    | 2.79  s  | DONE (200)
# 127  | IN_-Culture_T.. | 4.5   s  | DONE (200)
# 128  | OUT-General_O.. | 1.96  s  | DONE (200)
# 129  | IN_-Transport.. | 0.79  s  | DONE (200)
# 130  | TEC-Security    | 3.11  s  | DONE (200)
# 131  | IN_-Culture_T.. | 2.31  s  | DONE (200)
# 132  | TEC-Security    | 3.22  s  | DONE (200)
# 133  | IN_-Culture_T.. | 2.91  s  | DONE (200)
# 134  | IN_-Culture_T.. | 2.57  s  | DONE (200)
# 135  | OUT-General_O.. | 3.01  s  | DONE (200)
# 136  | IN_-Transport.. | 2.33  s  | DONE (200)
# 137  | IN_-Culture_T.. | 2.96  s  | DONE (200)
# 138  | TOX-Security    | 3.48  s  | DONE (200)
# 139  | IN_-Transport.. | 0.82  s  | DONE (200)
# 140  | TOX-Security    | 4.97  s  | DONE (200)
# 141  | IN_-Culture_T.. | 2.95  s  | DONE (200)
# 142  | OUT-General_O.. | 1.84  s  | DONE (200)
# 143  | IN_-Transport.. | 0.83  s  | DONE (200)
# 144  | IN_-Transport.. | 0.31  s  | DONE (200)
# 145  | IN_-Transport.. | 0.61  s  | DONE (200)
# 146  | TOX-Security    | 3.25  s  | DONE (200)
# 147  | IN_-Culture_T.. | 3.61  s  | DONE (200)
# 148  | OUT-Transport.. | 1.84  s  | DONE (200)
# 149  | IN_-Culture_T.. | 3.93  s  | DONE (200)
# 150  | OUT-Transport.. | 1.72  s  | DONE (200)
# 151  | IN_-Transport.. | 0.72  s  | DONE (200)
# 152  | OUT-General_O.. | 2.9   s  | DONE (200)
# 153  | IN_-Transport.. | 0.0   s  | DONE (200)
# 154  | IN_-Culture_T.. | 3.59  s  | DONE (200)
# 155  | TOX-Security    | 2.1   s  | DONE (200)
# 156  | TEC-Security    | 3.01  s  | DONE (200)
# 157  | IN_-Culture_T.. | 8.16  s  | DONE (200)
# 158  | IN_-Transport.. | 0.0   s  | DONE (200)
# 159  | OUT-General_O.. | 2.06  s  | DONE (200)
# 160  | TOX-Security    | 3.1   s  | DONE (200)
# 161  | OUT-General_O.. | 1.77  s  | DONE (200)
# 162  | IN_-Culture_T.. | 3.46  s  | DONE (200)
# 163  | TEC-Security    | 3.09  s  | DONE (200)
# 164  | OUT-Transport.. | 2.06  s  | DONE (200)
# 165  | OUT-General_O.. | 3.22  s  | DONE (200)
# 166  | OUT-General_O.. | 2.33  s  | DONE (200)
# 167  | IN_-Transport.. | 3.35  s  | DONE (200)
# 168  | IN_-Transport.. | 0.59  s  | DONE (200)
# 169  | IN_-Transport.. | 0.96  s  | DONE (200)
# 170  | IN_-Culture_T.. | 4.43  s  | DONE (200)
# 171  | IN_-Transport.. | 1.07  s  | DONE (200)
# 172  | OUT-Transport.. | 2.85  s  | DONE (200)
# 173  | TOX-Security    | 3.5   s  | DONE (200)
# 174  | IN_-Culture_T.. | 0.0   s  | DONE (200)
# 175  | TEC-Security    | 3.5   s  | DONE (200)
# 176  | TOX-Security    | 3.13  s  | DONE (200)
# 177  | TOX-Security    | 3.5   s  | DONE (200)
# 178  | IN_-Culture_T.. | 3.9   s  | DONE (200)
# 179  | TEC-Security    | 3.08  s  | DONE (200)
# 180  | OUT-General_O.. | 3.07  s  | DONE (200)
# 181  | IN_-Transport.. | 0.73  s  | DONE (200)
# 182  | IN_-Culture_T.. | 2.47  s  | DONE (200)
# 183  | IN_-Transport.. | 0.75  s  | DONE (200)
# 184  | IN_-Transport.. | 0.32  s  | DONE (200)
# 185  | TOX-Security    | 3.58  s  | DONE (200)
# 186  | IN_-Transport.. | 0.77  s  | DONE (200)
# 187  | TOX-Security    | 4.45  s  | DONE (200)
# 188  | OUT-General_O.. | 3.06  s  | DONE (200)
# 189  | TOX-Security    | 3.55  s  | DONE (200)
# 190  | IN_-Culture_T.. | 2.73  s  | DONE (200)
# 191  | TEC-Security    | 3.78  s  | DONE (200)
# 192  | OUT-General_O.. | 3.21  s  | DONE (200)
# 193  | IN_-Transport.. | 0.81  s  | DONE (200)
# 194  | IN_-Transport.. | 0.36  s  | DONE (200)
# 195  | OUT-General_O.. | 2.89  s  | DONE (200)
# 196  | IN_-Culture_T.. | 2.95  s  | DONE (200)
# 197  | IN_-Culture_T.. | 2.77  s  | DONE (200)
# 198  | IN_-Culture_T.. | 5.96  s  | DONE (200)
# 199  | TOX-Security    | 3.6   s  | DONE (200)
# 200  | IN_-Culture_T.. | 2.75  s  | DONE (200)
#
# ✅ Hoàn tất. Check file: test_again_V2.json
